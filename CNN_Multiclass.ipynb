# %%
import os
import torch

# %%
pip install torch
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached torch-2.4.1-cp312-cp312-win_amd64.whl.metadata (27 kB)
# ...
#    ---------------------------------------- 0.0/199.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/199.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/199.4 MB 262.6 kB/s eta 0:12:40
#    ---------------------------------------- 0.0/199.4 MB 281.8 kB/s eta 0:11:48
#    ---------------------------------------- 0.1/199.4 MB 409.6 kB/s eta 0:08:07
#    ---------------------------------------- 0.1/199.4 MB 409.6 kB/s eta 0:08:07
#    ---------------------------------------- 0.2/199.4 MB 655.4 kB/s eta 0:05:04
#    ---------------------------------------- 0.2/199.4 MB 655.4 kB/s eta 0:05:04
#    ---------------------------------------- 0.3/199.4 MB 905.4 kB/s eta 0:03:40
#    ---------------------------------------- 0.3/199.4 MB 905.4 kB/s eta 0:03:40
# ...

# %%
train_directory = r'D:\Dataset\seg_train\seg_train'

# %%
IMAGE_SIZE = 224 # for every size
BATCH_SIZE = 64 # how many images will be worked in per epoch

#pre-processing
